# %%
# %sql
CREATE CATALOG IF NOT EXISTS open_meteo;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS open_meteo.bronze;

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN open_meteo;
